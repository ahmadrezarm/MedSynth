# %% [markdown]
# Promethus Score is wrong for GPT. Model said A, but the Score is recorded as B. Here I need to do it manually:

# %%
import pandas as pd

# %% [markdown]
# ## MS_AT_vs_NC_AT

# %%
MS_AT_vs_NC_AT= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/GPT_promethus_relative_score_MS_10k_and_Aci_NC_10k_and_Aci_2025-02-11.csv", sep="|")

# %%
for i in range(len(MS_AT_vs_NC_AT)):
    print(i)
    print(MS_AT_vs_NC_AT["feedback"][i])
    print(MS_AT_vs_NC_AT["Preference"][i])
    print(50*"$")
# Out:
# 0
# (Hallucination: Response A and Response B both avoid significant hallucinations, except Response A incorrectly mentions a family history of osteoarthritis and redundantly repeats details about the right elbow, which aren't supported by the conversation or the ground truth. Response B remains more consistent with facts without introducing such errors.) [RESULT] B
#
# (Critical Omissions: Response A and Response B both capture key information; however, Response B provides more detail about numbness and tingling in hands, incorporates both elbows, and mentions physical therapy plans, which are found in the conversation and ground truth. Response A lacks these details.) [RESULT] B
#
# (Professional Tone: Both Response A and Response B maintain a professional tone throughout, suitable for medical documentation.) [RESULT] B
#
# (Logical Structure: Both Response A and Response B follow a logical structure, presenting information in a coherent sequence.) [RESULT] B
#
# ...

# %% [markdown]
# ## MS_Only vs NC_Only

# %%
MS_Only_NC_Only= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/GPT_promethus_relative_score_MS_10k_Only_NC_10k_Only_2025-02-11.csv", sep="|")

# %%
for i in range(len(MS_Only_NC_Only)):
    print(i)
    print(MS_Only_NC_Only["feedback"][i])
    print(MS_Only_NC_Only["Preference"][i])
    print(50*"$")
# Out:
# 0
# (Hallucination) Response A includes unnecessary information not mentioned in the ground truth or conversation, such as the patient being "African American" and an "Elevated rheumatoid factor (RF) and antinuclear antibody (ANA)." These are hallucinations not supported by the provided dialogue or note. Response B, while lengthy, stays true to the dialogue and ground truth without introducing fabricated details. [RESULT] B
#
# (Critical Omissions) Response A omits mentioning the patient’s positive response to her past gout medication and the stability of her psoriasis in the narrative reported. Response B accurately reports the patient’s feedback on her conditions and treatments, including the positive response to medication for gout and the condition of psoriasis. [RESULT] B
#
# ...

# %% [markdown]
# ## MS_AT vs PM_AT

# %%
MS_AT_PM_AT= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/GPT_promethus_relative_score_MS_57_and_Aci_PriMock_and_Aci_2025-02-11.csv", sep="|")

# %%
for i in range(len(MS_AT_PM_AT)):
    print(i)
    print(MS_AT_PM_AT["feedback"][i])
    print(MS_AT_PM_AT["Preference"][i])
    print(50*"$")
# Out:
# 0
# (Hallucination) Response A contains hallucinated information such as Carolyn's last name being Smith instead of Garcia, and an incorrect report of skin lesion details. Response B, however, more accurately reflects the dialogue and the ground truth note, though it incorrectly states denial of numbness and tingling in hands, despite these being endorsed. Both responses include hallucinations, but Response B's error is slightly less impactful. [RESULT] B
#
# (Critical Omissions) Response A is missing important details like the patient's review of systems findings. Response B also omits certain elements, such as skin lesions being under control, but retains most critical information such as examination and plan details. However, Response A captures more relevant lab results. [RESULT] A
#
# (Professional Tone) Both responses maintain a consistent professional tone appropriate for medical summaries. There is no evident unprofessional language in either response. [RESULT] A
#
# ...

# %% [markdown]
# ## MS Only vs. PM Only

# %%
MS_Only_PM_Only= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/GPT_promethus_relative_score_MS_57_Only_PriMock_Only_2025-02-11.csv", sep="|")

# %%
for i in range(len(MS_Only_PM_Only)):
    print(i)
    print(MS_Only_PM_Only["feedback"][i])
    print(MS_Only_PM_Only["Preference"][i])
    print(50*"$")
# Out:
# 0
# (Hallucination: Response A provides a comprehensive summary that accurately reflects the dialogue and ground truth note, sticking closely to the converted details such as osteoarthritis flaring primarily in the patient's elbows, the stable condition of the gout and psoriasis, and accurate medication continuity. Response B condenses the information excessively, causing it to lose several nuanced points, such as the relief measures the patient takes for numbness. Therefore, Response A performs better in avoiding hallucination.) [RESULT] A
#
# ...

# %% [markdown]
# # Qwen

# %% [markdown]
# ## MS_AT vs. NC_AT

# %%
import pandas as pd
ms_at_NC_AT_qwen= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/Qwen_relative_score_MS_10k_and_Aci_NC_10k_and_Aci_2025-02-11.csv", sep= "|")

# %%
for i in range(len(ms_at_NC_AT_qwen)):
    print(i)
    print(ms_at_NC_AT_qwen["feedback"][i])
    print(50*"$")
# Out:
# 0
# Feedback: Both responses cover the subjective symptoms provided by the patient well. However, Model A includes additional context found in the ground truth note which enhances the overall accuracy and detail level of the summary. Model B lacks this detail, making it slightly less comprehensive compared to Model A despite being accurate. Both responses adequately address the objective findings and assessment made by the doctor, but Model A again stands out due to its inclusion of the plan derived from the ground truth note. Overall, while both models adhere closely to the required structure and key details from the conversation, Model A provides a more thorough summary by incorporating relevant information from the ground truth note, leading to a higher alignment with the score rubric. [RESULT] A
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# ...

# %% [markdown]
# ## MS Only vs. NC Only

# %%
df= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/Qwen_relative_score_MS_10k_Only_NC_10k_Only_2025-02-11.csv", sep="|")

# %%
for i in range(len(df)):
    print(i)
    print(df["feedback"][i])
    print(50*"$")
# Out:
# 0
# Feedback: Both Model A and Model B captured the essential elements from the conversation, but Model A did a better job integrating additional context from the ground truth note into the summary, particularly regarding certain nuances and background details pertinent to the patient’s condition. While Model B provided an accurate summary, it lacked some of the depth found in Model A's summary which included more detailed observations and patient history noted in the ground truth document. [RESULT] A
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# ...

# %% [markdown]
# ## MS_AT vs. PM_AT

# %%
df= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/Qwen_relative_score_MS_57_and_Aci_PriMock_and_Aci_2025-02-11.csv", sep="|")
for i in range(len(df)):
    print(i)
    print(df["feedback"][i])
    print(50*"$")
# Out:
# 0
# Feedback: Both responses attempt to cover the subjective and objective aspects of the patient's visit but differ significantly in their assessment and plan sections. Model A captures the subjective and objective points accurately, though its assessment section is vague and does not clearly state the diagnosis. The plan section is missing entirely, which is critical for understanding the next steps. On the other hand, Model B provides a clear assessment and includes a thorough plan. It adheres more closely to the structure required by including all necessary components—subjective, objective, assessment, and plan—ensuring that the summary is comprehensive and useful for medical purposes. [RESULT] B
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# ...

# %% [markdown]
# ## MS Only vs PM Only

# %%
df= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/Qwen_relative_score_MS_57_Only_PriMock_Only_2025-02-11.csv", sep="|")
for i in range(len(df)):
    print(i)
    print(df["feedback"][i])
    print(50*"$")
# Out:
# 0
# Feedback: Both models provide summaries that incorporate elements from the conversation and the ground truth note. Model A captures most of the key details but lacks some nuanced information about the patient’s symptoms and misses out on one aspect of the doctor’s assessment. Model B, however, does a more thorough job capturing all relevant aspects of the conversation, including symptoms, objective findings, assessment, and plan, aligning closely with the ground truth note. [RESULT] B
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# ...

# %%
import pandas as pd
prom= pd.read_csv("/h/ahmad/SynthDataGen_v2/Synthetic_Data_Gen/data/eval_results/cont_eval/llm_eval_v2/reltive_scores/N2D/qwen_fixed/N2D_Qwen_relative_score_N2D_MS_10k_and_Aci_NC_10k_and_Aci_2025-02-12.csv", sep="|")
for i in range(len(prom)):
    print(i)
    print(prom["feedback"][i])
    #print(prom["Preference"][i])

    print(50*"$")
# Out:
# 0
# Feedback: The evaluation focuses on the accuracy of the reconstructed conversation based on the provided summary note. Model A's response captures the essence of the patient's concerns and medical advice as mentioned in the note but misses out on incorporating some of the subtle nuances found in the ground truth dialogue. Model B's response, however, closely mirrors the ground truth dialogue by not only capturing the main points discussed but also the emotional tone and specific details which are essential for a realistic interaction. Considering the rubric, Model B achieves higher accuracy in reconstructing the doctor-patient conversation based on the summary note. [RESULT] B
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# 1
# ...

# %% [markdown]
# Extract scores from preferences:
